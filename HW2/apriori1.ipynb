# %%
from pyspark import SparkContext
from pyspark import SparkConf

conf = SparkConf().setAppName("apriori")
sc = SparkContext(conf=conf)

# %%
data = sc.textFile('browsing.txt')
data.take(5)
# Out:
# ['FRO11987 ELE17451 ELE89019 SNA90258 GRO99222 ',
#  'GRO99222 GRO12298 FRO12685 ELE91550 SNA11465 ELE26917 ELE52966 FRO90334 SNA30755 ELE17451 FRO84225 SNA80192 ',
#  'ELE17451 GRO73461 DAI22896 SNA99873 FRO86643 ',
#  'ELE17451 ELE37798 FRO86643 GRO56989 ELE23393 SNA11465 ',
#  'ELE17451 SNA69641 FRO86643 FRO78087 SNA11465 GRO39357 ELE28573 ELE11375 DAI54444 ']

# %%
def generate_next_c(f_k, k):
    next_c = [var1 | var2 for index, var1 in enumerate(f_k) for var2 in f_k[index + 1:] if
              list(var1)[:k - 2] == list(var2)[:k - 2]]
    return next_c

# %%
def generate_f_k(sc, c_k, shared_itemset, sup):
    def get_sup(x):
        x_sup = len([1 for t in shared_itemset.value if x.issubset(t)])
        if x_sup >= sup:
            return x, x_sup
        else:
            return ()

    f_k = sc.parallelize(c_k).map(get_sup).filter(lambda x: x).collect()
    return f_k

# %% [markdown]
# # For k = 1

# %%
n_samples = data.count()
print(n_samples)
# Out:
# 31101

# %%
sup = 100

# %%
itemset = data.map(lambda line: sorted([str(item) for item in line.strip().split(' ')]))
itemset.take(5)
# Out:
# [['ELE17451', 'ELE89019', 'FRO11987', 'GRO99222', 'SNA90258'],
#  ['ELE17451',
#   'ELE26917',
#   'ELE52966',
#   'ELE91550',
#   'FRO12685',
#   'FRO84225',
#   'FRO90334',
#   'GRO12298',
#   'GRO99222',
#   'SNA11465',
#   'SNA30755',
#   'SNA80192'],
#  ['DAI22896', 'ELE17451', 'FRO86643', 'GRO73461', 'SNA99873'],
#  ['ELE17451', 'ELE23393', 'ELE37798', 'FRO86643', 'GRO56989', 'SNA11465'],
#  ['DAI54444',
#   'ELE11375',
#   'ELE17451',
#   'ELE28573',
#   'FRO78087',
#   'FRO86643',
#   'GRO39357',
#   'SNA11465',
#   'SNA69641']]

# %%
shared_itemset = sc.broadcast(itemset.map(lambda x: set(x)).collect())
# shared_itemset.take(5)

# %%
frequent_itemset = []

# prepare candidate_1
k = 1
c_k = itemset.flatMap(lambda x: set(x)).distinct().collect()
c_k = [{x} for x in c_k]
c_k[:4]
# Out:
# [{'FRO11987'}, {'SNA90258'}, {'FRO90334'}, {'SNA80192'}]

# %%
print("C{}: {}".format(k, c_k))
f_k = generate_f_k(sc, c_k, shared_itemset, sup)
# Out:
# C1: [{'FRO11987'}, {'SNA90258'}, {'FRO90334'}, {'SNA80192'}, {'ELE91550'}, {'FRO84225'}, {'ELE52966'}, {'GRO73461'}, {'DAI22896'}, {'FRO86643'}, {'ELE23393'}, {'SNA69641'}, {'GRO39357'}, {'ELE11375'}, {'DAI50921'}, {'GRO75578'}, {'SNA91554'}, {'DAI22177'}, {'SNA85662'}, {'ELE59935'}, {'DAI14125'}, {'ELE66810'}, {'DAI91535'}, {'DAI49199'}, {'DAI54690'}, {'FRO76833'}, {'GRO12935'}, {'SNA55952'}, {'ELE82555'}, {'GRO36567'}, {'GRO48282'}, {'DAI87514'}, {'FRO82427'}, {'DAI48891'}, {'FRO47475'}, {'DAI17810'}, {'ELE11111'}, {'FRO76487'}, {'FRO92261'}, {'SNA66979'}, {'GRO49037'}, {'DAI88808'}, {'ELE52446'}, {'FRO41069'}, {'FRO16142'}, {'FRO70974'}, {'DAI22534'}, {'ELE76964'}, {'FRO19520'}, {'FRO24098'}, {'FRO13639'}, {'FRO98878'}, {'FRO38366'}, {'SNA59903'}, {'DAI55911'}, {'FRO31317'}, {'SNA72163'}, {'DAI18334'}, {'ELE20196'}, {'FRO60023'}, {'GRO94047'}, {'SNA40380'}, {'FRO98184'}, {'ELE30182'}, {'SNA45033'}, {'FRO70489'}, {'DAI63921'}, {'FRO74481'}, {'SNA18336'}, {'FRO62970'}, {'SNA83730'}, {'SNA85034'}, {'DAI91290'}, {'GRO68850'}, {'SNA14713'}, {'DAI32480'}, {'GRO27756'}, {'SNA93641'}, {'DAI69239'}, {'GRO17442'}, {'ELE41924'}, {'SNA62203'}, {'DAI49253'}, {'DAI47060'}, {'FRO35353'}, {'DAI48919'}, {'SNA93730'}, {'SNA81153'}, {'SNA89670'}, {'DAI84001'}, {'ELE12792'}, {'SNA46341'}, {'ELE28189'}, {'ELE63685'}, {'ELE11474'}, {'GRO86568'}, {'ELE13292'}, {'SNA56035'}, {'GRO92942'}, {'ELE86561'}, {'GRO84328'}, {'GRO85051'}, {'FRO37380'}, {'SNA62579'}, {'DAI25796'}, {'DAI73122'}, {'ELE64231'}, {'ELE49863'}, {'FRO53137'}, {'FRO21081'}, {'FRO94523'}, {'GRO11981'}, {'ELE67472'}, {'SNA63636'}, {'GRO15448'}, {'DAI37889'}, {'SNA85241'}, {'FRO73056'}, {'DAI35798'}, {'FRO98059'}, {'SNA99039'}, {'SNA64534'}, {'FRO16323'}, {'ELE32164'}, {'ELE37770'}, {'GRO61641'}, {'DAI88807'}, {'GRO92635'}, {'FRO89949'}, {'FRO27054'}, {'ELE85027'}, {'GRO91966'}, {'FRO66272'}, {'SNA19759'}, {'FRO53564'}, {'SNA36781'}, {'GRO30299'}, {'FRO20561'}, {'DAI88079'}, {'FRO55003'}, {'DAI29878'}, {'SNA80324'}, {'SNA50326'}, {'SNA23339'}, {'ELE38504'}, {'SNA88283'}, {'DAI75645'}, {'ELE92204'}, {'GRO51041'}, {'SNA12663'}, {'ELE92629'}, {'FRO61611'}, {'ELE25211'}, {'FRO20226'}, {'ELE66757'}, {'FRO76276'}, {'GRO62138'}, {'SNA61084'}, {'SNA96271'}, {'SNA83597'}, {'ELE49801'}, {'SNA46675'}, {'SNA68714'}, {'GRO50832'}, {'ELE83520'}, {'ELE36406'}, {'DAI67621'}, {'SNA97586'}, {'GRO68067'}, {'ELE15527'}, {'GRO89766'}, {'ELE76156'}, {'FRO85978'}, {'SNA24799'}, {'GRO24861'}, {'SNA99654'}, {'DAI34345'}, {'SNA87654'}, {'FRO74605'}, {'SNA55617'}, {'SNA57913'}, {'DAI94514'}, {'SNA94736'}, {'SNA38068'}, {'DAI51880'}, {'ELE88263'}, {'SNA17775'}, {'SNA30253'}, {'DAI80076'}, {'FRO41952'}, {'DAI13788'}, {'ELE81989'}, {'GRO58055'}, {'ELE74009'}, {'FRO18950'}, {'FRO59665'}, {'FRO62184'}, {'DAI99781'}, {'GRO56726'}, {'DAI36147'}, {'DAI74875'}, {'GRO90829'}, {'SNA98569'}, {'DAI71593'}, {'FRO35729'}, {'GRO70170'}, {'GRO92640'}, {'ELE30196'}, {'ELE57042'}, {'GRO52067'}, {'FRO93457'}, {'DAI27411'}, {'ELE60430'}, {'FRO89565'}, {'SNA49028'}, {'SNA11666'}, {'GRO73510'}, {'DAI96940'}, {'GRO20471'}, {'DAI62356'}, {'SNA44451'}, {'ELE38289'}, {'FRO90806'}, {'SNA12933'}, {'DAI45720'}, {'SNA12119'}, {'DAI35876'}, {'ELE48774'}, {'ELE69675'}, {'GRO37082'}, {'GRO58671'}, {'DAI16281'}, {'DAI54949'}, {'ELE44423'}, {'DAI61225'}, {'FRO91499'}, {'SNA85209'}, {'SNA77112'}, {'ELE87456'}, {'FRO57752'}, {'FRO75586'}, {'ELE22970'}, {'DAI75981'}, {'GRO38949'}, {'DAI26390'}, {'DAI45339'}, {'FRO89483'}, {'FRO66216'}, {'SNA45733'}, {'GRO17503'}, {'GRO87006'}, {'SNA63068'}, {'ELE30327'}, {'DAI15681'}, {'ELE19182'}, {'ELE93521'}, {'SNA35625'}, {'FRO94302'}, {'GRO36457'}, {'DAI66393'}, {'GRO55545'}, {'FRO41430'}, {'ELE29694'}, {'FRO63707'}, {'SNA80523'}, {'FRO59919'}, {'ELE56788'}, {'ELE26032'}, {'ELE63993'}, {'FRO55853'}, {'GRO88324'}, {'ELE25077'}, {'ELE20202'}, {'SNA50124'}, {'FRO74121'}, {'SNA30373'}, {'SNA94104'}, {'ELE91843'}, {'ELE76310'}, {'FRO52367'}, {'GRO83595'}, {'ELE49861'}, {'GRO86826'}, {'FRO76811'}, {'ELE55721'}, {'ELE ...

# %%
print(len(c_k))
print(len(f_k))
print(f_k)
# Out:
# 12592
# 647
# [({'FRO11987'}, 104), ({'SNA90258'}, 550), ({'SNA80192'}, 258), ({'ELE52966'}, 380), ({'GRO73461'}, 3602), ({'DAI22896'}, 1219), ({'FRO86643'}, 235), ({'SNA69641'}, 599), ({'GRO39357'}, 296), ({'ELE11375'}, 214), ({'DAI50921'}, 350), ({'SNA91554'}, 208), ({'DAI22177'}, 1627), ({'SNA85662'}, 349), ({'ELE59935'}, 1311), ({'DAI14125'}, 163), ({'ELE66810'}, 1697), ({'DAI49199'}, 664), ({'GRO12935'}, 169), ({'SNA55952'}, 1094), ({'GRO36567'}, 832), ({'GRO48282'}, 184), ({'DAI87514'}, 254), ({'DAI48891'}, 825), ({'ELE11111'}, 811), ({'FRO92261'}, 915), ({'SNA66979'}, 703), ({'DAI88808'}, 123), ({'FRO41069'}, 409), ({'FRO16142'}, 931), ({'DAI22534'}, 287), ({'FRO19520'}, 133), ({'FRO24098'}, 521), ({'FRO98878'}, 157), ({'FRO38366'}, 353), ({'SNA59903'}, 891), ({'DAI55911'}, 974), ({'FRO31317'}, 2330), ({'SNA72163'}, 1090), ({'ELE20196'}, 545), ({'FRO98184'}, 480), ({'ELE30182'}, 274), ({'DAI63921'}, 1773), ({'SNA18336'}, 709), ({'FRO62970'}, 115), ({'SNA83730'}, 379), ({'DAI91290'}, 1138), ({'SNA14713'}, 188), ({'DAI32480'}, 165), ({'SNA93641'}, 240), ({'GRO17442'}, 101), ({'SNA93730'}, 320), ({'SNA89670'}, 169), ({'DAI84001'}, 363), ({'ELE12792'}, 832), ({'ELE28189'}, 361), ({'ELE63685'}, 176), ({'SNA56035'}, 148), ({'ELE86561'}, 735), ({'GRO84328'}, 299), ({'GRO85051'}, 1214), ({'FRO37380'}, 117), ({'SNA62579'}, 106), ({'DAI25796'}, 127), ({'DAI73122'}, 566), ({'ELE64231'}, 139), ({'ELE49863'}, 406), ({'FRO53137'}, 190), ({'FRO21081'}, 436), ({'FRO94523'}, 390), ({'GRO15448'}, 237), ({'SNA85241'}, 335), ({'FRO73056'}, 728), ({'DAI35798'}, 226), ({'SNA64534'}, 351), ({'ELE32164'}, 2851), ({'ELE37770'}, 630), ({'GRO61641'}, 320), ({'DAI88807'}, 1316), ({'GRO92635'}, 136), ({'FRO27054'}, 229), ({'ELE85027'}, 478), ({'FRO66272'}, 927), ({'SNA36781'}, 165), ({'DAI88079'}, 452), ({'FRO55003'}, 189), ({'DAI29878'}, 114), ({'SNA80324'}, 3044), ({'ELE38504'}, 271), ({'SNA88283'}, 865), ({'DAI75645'}, 2736), ({'SNA12663'}, 523), ({'ELE92629'}, 336), ({'FRO61611'}, 205), ({'SNA96271'}, 1295), ({'SNA83597'}, 130), ({'ELE49801'}, 663), ({'GRO50832'}, 608), ({'DAI67621'}, 384), ({'SNA97586'}, 178), ({'GRO68067'}, 651), ({'ELE15527'}, 332), ({'FRO85978'}, 1918), ({'SNA24799'}, 504), ({'SNA99654'}, 234), ({'FRO74605'}, 261), ({'SNA55617'}, 389), ({'SNA57913'}, 244), ({'DAI94514'}, 129), ({'SNA38068'}, 811), ({'DAI51880'}, 375), ({'ELE88263'}, 397), ({'SNA17775'}, 167), ({'DAI80076'}, 232), ({'DAI13788'}, 213), ({'GRO58055'}, 113), ({'ELE74009'}, 1816), ({'GRO56726'}, 1784), ({'FRO35729'}, 438), ({'ELE30196'}, 121), ({'GRO52067'}, 315), ({'FRO89565'}, 516), ({'SNA49028'}, 150), ({'DAI62356'}, 177), ({'SNA44451'}, 175), ({'ELE38289'}, 517), ({'SNA12933'}, 189), ({'ELE69675'}, 223), ({'GRO58671'}, 120), ({'ELE87456'}, 655), ({'FRO75586'}, 762), ({'ELE22970'}, 252), ({'DAI26390'}, 243), ({'DAI45339'}, 159), ({'FRO66216'}, 157), ({'GRO87006'}, 291), ({'ELE30327'}, 183), ({'DAI15681'}, 132), ({'SNA35625'}, 199), ({'GRO55545'}, 138), ({'ELE56788'}, 1345), ({'GRO88324'}, 715), ({'ELE25077'}, 478), ({'ELE20202'}, 317), ({'FRO74121'}, 179), ({'SNA94104'}, 107), ({'ELE76310'}, 102), ({'ELE49861'}, 397), ({'ELE55721'}, 169), ({'ELE50215'}, 113), ({'ELE74482'}, 1316), ({'ELE61961'}, 265), ({'FRO49682'}, 156), ({'SNA53220'}, 580), ({'ELE24630'}, 321), ({'ELE67409'}, 135), ({'DAI20585'}, 120), ({'SNA74022'}, 286), ({'SNA26242'}, 218), ({'GRO89004'}, 308), ({'DAI56158'}, 153), ({'GRO91660'}, 212), ({'FRO61354'}, 450), ({'SNA44190'}, 437), ({'SNA67745'}, 151), ({'GRO69388'}, 121), ({'SNA38067'}, 164), ({'SNA68538'}, 344), ({'DAI51778'}, 100), ({'GRO93309'}, 108), ({'SNA17270'}, 236), ({'ELE11909'}, 131), ({'GRO64900'}, 1046), ({'GRO71621'}, 1920), ({'FRO71085'}, 337), ({'FRO47796'}, 102), ({'GRO65522'}, 288), ({'GRO82670'}, 459), ({'DAI48423'}, 218), ({'DAI11778'}, 117), ({'DAI87507'}, 213), ({'DAI67189'}, 280), ({'FRO33641'}, 146), ({'ELE78169'}, 558), ({'SNA41431'}, 144), ({'FRO47962'}, 306), ({'ELE42696'}, 200), ({'FRO87724'}, 208), ({'GRO61273'}, 439), ({'GRO8 ...

# %%
frequent_itemset.append(f_k)

# %% [markdown]
# # For k = 2

# %%
c_k = generate_next_c([set(item) for item in map(lambda x: x[0], f_k)], 2)

# %%
f_k = generate_f_k(sc, c_k, shared_itemset, sup)
print(f_k)
# Out:
# [({'SNA90258', 'ELE17451'}, 113), ({'GRO99222', 'SNA90258'}, 156), ({'DAI62779', 'SNA90258'}, 114), ({'GRO73461', 'DAI22896'}, 304), ({'GRO73461', 'SNA69641'}, 150), ({'GRO73461', 'DAI22177'}, 248), ({'ELE59935', 'GRO73461'}, 116), ({'GRO73461', 'ELE66810'}, 228), ({'GRO73461', 'SNA55952'}, 117), ({'GRO73461', 'GRO36567'}, 117), ({'GRO73461', 'DAI48891'}, 117), ({'ELE11111', 'GRO73461'}, 158), ({'FRO16142', 'GRO73461'}, 197), ({'GRO73461', 'FRO24098'}, 112), ({'SNA59903', 'GRO73461'}, 123), ({'GRO73461', 'DAI55911'}, 116), ({'FRO31317', 'GRO73461'}, 395), ({'SNA72163', 'GRO73461'}, 285), ({'DAI63921', 'GRO73461'}, 219), ({'SNA18336', 'GRO73461'}, 121), ({'GRO73461', 'DAI91290'}, 161), ({'ELE12792', 'GRO73461'}, 116), ({'GRO73461', 'GRO85051'}, 147), ({'DAI73122', 'GRO73461'}, 146), ({'FRO73056', 'GRO73461'}, 195), ({'GRO73461', 'ELE32164'}, 486), ({'DAI88807', 'GRO73461'}, 313), ({'GRO73461', 'FRO66272'}, 110), ({'GRO73461', 'DAI88079'}, 145), ({'GRO73461', 'SNA80324'}, 562), ({'GRO73461', 'SNA88283'}, 118), ({'DAI75645', 'GRO73461'}, 712), ({'SNA12663', 'GRO73461'}, 109), ({'GRO73461', 'SNA96271'}, 225), ({'ELE49801', 'GRO73461'}, 122), ({'GRO73461', 'GRO68067'}, 145), ({'GRO73461', 'FRO85978'}, 344), ({'GRO73461', 'FRO74605'}, 105), ({'GRO73461', 'SNA38068'}, 212), ({'GRO73461', 'ELE74009'}, 345), ({'GRO73461', 'GRO56726'}, 324), ({'GRO73461', 'ELE87456'}, 104), ({'ELE56788', 'GRO73461'}, 102), ({'GRO73461', 'ELE74482'}, 168), ({'GRO73461', 'FRO61354'}, 117), ({'GRO73461', 'SNA44190'}, 117), ({'GRO64900', 'GRO73461'}, 141), ({'GRO73461', 'GRO71621'}, 305), ({'GRO73461', 'FRO47962'}, 137), ({'GRO88511', 'GRO73461'}, 100), ({'GRO32086', 'GRO73461'}, 102), ({'GRO73461', 'ELE20847'}, 187), ({'GRO73461', 'DAI55148'}, 135), ({'GRO73461', 'GRO81647'}, 332), ({'DAI85309', 'GRO73461'}, 338), ({'GRO73461', 'FRO19221'}, 202), ({'DAI87448', 'GRO73461'}, 231), ({'GRO73461', 'DAI92600'}, 254), ({'GRO73461', 'ELE17451'}, 580), ({'GRO73461', 'ELE26917'}, 255), ({'SNA99873', 'GRO73461'}, 296), ({'GRO73461', 'ELE37798'}, 108), ({'GRO73461', 'FRO78087'}, 192), ({'GRO73461', 'GRO94758'}, 168), ({'SNA47306', 'GRO73461'}, 103), ({'FRO32293', 'GRO73461'}, 200), ({'GRO73461', 'DAI95741'}, 121), ({'GRO30386', 'GRO73461'}, 380), ({'GRO73461', 'SNA93860'}, 111), ({'GRO15017', 'GRO73461'}, 288), ({'GRO59710', 'GRO73461'}, 305), ({'GRO73461', 'ELE66600'}, 218), ({'DAI62779', 'GRO73461'}, 1139), ({'GRO73461', 'ELE14480'}, 196), ({'SNA55762', 'GRO73461'}, 222), ({'ELE91337', 'GRO73461'}, 174), ({'ELE68605', 'GRO73461'}, 113), ({'GRO73461', 'SNA45677'}, 318), ({'GRO73461', 'FRO40251'}, 882), ({'GRO73461', 'FRO43226'}, 110), ({'GRO73461', 'ELE20398'}, 111), ({'GRO73461', 'GRO69543'}, 320), ({'GRO73461', 'GRO44993'}, 227), ({'GRO73461', 'GRO61133'}, 250), ({'GRO73461', 'GRO35122'}, 187), ({'GRO73461', 'GRO81087'}, 172), ({'ELE62598', 'GRO73461'}, 121), ({'GRO73461', 'GRO21487'}, 631), ({'GRO73461', 'DAI43223'}, 184), ({'SNA59061', 'GRO73461'}, 109), ({'FRO92469', 'GRO73461'}, 213), ({'GRO73461', 'GRO38814'}, 427), ({'GRO73461', 'ELE99737'}, 155), ({'DAI83948', 'GRO73461'}, 156), ({'GRO73461', 'FRO35904'}, 162), ({'GRO73461', 'SNA95666'}, 116), ({'FRO53271', 'GRO73461'}, 192), ({'SNA90094', 'GRO73461'}, 160), ({'GRO73461', 'ELE34057'}, 217), ({'GRO73461', 'DAI31081'}, 283), ({'DAI83733', 'GRO73461'}, 225), ({'GRO73461', 'FRO80039'}, 209), ({'GRO73461', 'SNA62128'}, 111), ({'DAI42493', 'GRO73461'}, 144), ({'GRO73461', 'GRO46854'}, 389), ({'ELE92920', 'GRO73461'}, 108), ({'SNA42528', 'GRO73461'}, 116), ({'GRO73461', 'ELE30933'}, 119), ({'FRO31317', 'DAI22896'}, 167), ({'SNA72163', 'DAI22896'}, 227), ({'DAI22896', 'ELE32164'}, 107), ({'DAI22896', 'SNA80324'}, 195), ({'DAI75645', 'DAI22896'}, 215), ({'DAI22896', 'ELE74009'}, 165), ({'DAI22896', 'ELE17451'}, 193), ({'GRO30386', 'DAI22896'}, 102), ({'DAI62779', 'DAI22896'}, 297), ({'DAI22896', 'FRO40251'}, 154), ({'DAI22896', 'GRO61133'}, 110), ({'GRO21487', 'DAI22896'}, 114), ({'DAI22896', 'GRO38814'}, 223), ({'FR ...

# %%
frequent_itemset.append(f_k)

# %% [markdown]
# # For k = 3

# %%
c_k = generate_next_c([set(item) for item in map(lambda x: x[0], f_k)], 3)
print(c_k)
# Out:
# [{'GRO99222', 'SNA90258', 'SNA80324'}, {'GRO99222', 'SNA90258', 'ELE17451'}, {'ELE26917', 'GRO99222', 'SNA90258'}, {'GRO99222', 'SNA90258', 'FRO40251'}, {'DAI62779', 'GRO73461', 'SNA90258'}, {'DAI62779', 'DAI22896', 'SNA90258'}, {'DAI62779', 'SNA90258', 'SNA69641'}, {'DAI62779', 'SNA90258', 'DAI50921'}, {'DAI62779', 'SNA90258', 'DAI22177'}, {'DAI62779', 'ELE59935', 'SNA90258'}, {'DAI62779', 'SNA90258', 'ELE66810'}, {'DAI62779', 'SNA90258', 'DAI49199'}, {'DAI62779', 'SNA90258', 'SNA55952'}, {'DAI62779', 'SNA90258', 'GRO36567'}, {'DAI62779', 'DAI48891', 'SNA90258'}, {'DAI62779', 'ELE11111', 'SNA90258'}, {'DAI62779', 'FRO92261', 'SNA90258'}, {'DAI62779', 'FRO16142', 'SNA90258'}, {'DAI62779', 'FRO24098', 'SNA90258'}, {'DAI62779', 'SNA59903', 'SNA90258'}, {'DAI62779', 'SNA90258', 'DAI55911'}, {'DAI62779', 'FRO31317', 'SNA90258'}, {'DAI62779', 'SNA72163', 'SNA90258'}, {'DAI62779', 'ELE20196', 'SNA90258'}, {'DAI62779', 'SNA90258', 'FRO98184'}, {'DAI62779', 'DAI63921', 'SNA90258'}, {'DAI62779', 'SNA18336', 'SNA90258'}, {'DAI62779', 'DAI91290', 'SNA90258'}, {'DAI62779', 'ELE12792', 'SNA90258'}, {'DAI62779', 'SNA90258', 'ELE86561'}, {'DAI62779', 'SNA90258', 'GRO85051'}, {'DAI62779', 'FRO73056', 'SNA90258'}, {'DAI62779', 'SNA90258', 'ELE32164'}, {'DAI62779', 'SNA90258', 'ELE37770'}, {'DAI62779', 'DAI88807', 'SNA90258'}, {'DAI62779', 'SNA90258', 'ELE85027'}, {'DAI62779', 'FRO66272', 'SNA90258'}, {'DAI62779', 'SNA90258', 'DAI88079'}, {'DAI62779', 'SNA90258', 'SNA80324'}, {'DAI62779', 'SNA88283', 'SNA90258'}, {'DAI62779', 'DAI75645', 'SNA90258'}, {'DAI62779', 'SNA12663', 'SNA90258'}, {'DAI62779', 'SNA90258', 'SNA96271'}, {'DAI62779', 'ELE49801', 'SNA90258'}, {'DAI62779', 'GRO50832', 'SNA90258'}, {'DAI62779', 'SNA90258', 'GRO68067'}, {'DAI62779', 'SNA90258', 'FRO85978'}, {'DAI62779', 'SNA90258', 'SNA24799'}, {'DAI62779', 'SNA90258', 'SNA55617'}, {'DAI62779', 'SNA38068', 'SNA90258'}, {'DAI62779', 'SNA90258', 'ELE74009'}, {'DAI62779', 'SNA90258', 'GRO56726'}, {'DAI62779', 'SNA90258', 'FRO89565'}, {'DAI62779', 'ELE87456', 'SNA90258'}, {'DAI62779', 'SNA90258', 'FRO75586'}, {'DAI62779', 'ELE56788', 'SNA90258'}, {'DAI62779', 'ELE25077', 'SNA90258'}, {'DAI62779', 'ELE74482', 'SNA90258'}, {'DAI62779', 'SNA53220', 'SNA90258'}, {'DAI62779', 'SNA90258', 'ELE24630'}, {'DAI62779', 'SNA74022', 'SNA90258'}, {'DAI62779', 'FRO61354', 'SNA90258'}, {'DAI62779', 'SNA90258', 'SNA44190'}, {'DAI62779', 'GRO64900', 'SNA90258'}, {'DAI62779', 'GRO71621', 'SNA90258'}, {'DAI62779', 'SNA90258', 'GRO82670'}, {'DAI62779', 'DAI67189', 'SNA90258'}, {'DAI62779', 'ELE78169', 'SNA90258'}, {'DAI62779', 'GRO88511', 'SNA90258'}, {'DAI62779', 'GRO32086', 'SNA90258'}, {'DAI62779', 'ELE20847', 'SNA90258'}, {'DAI62779', 'SNA90258', 'SNA50789'}, {'DAI62779', 'FRO99372', 'SNA90258'}, {'DAI62779', 'SNA90258', 'GRO95519'}, {'DAI62779', 'SNA90258', 'DAI55148'}, {'DAI62779', 'SNA90258', 'GRO81647'}, {'DAI62779', 'SNA49107', 'SNA90258'}, {'DAI62779', 'SNA90258', 'DAI22240'}, {'DAI62779', 'SNA82528', 'SNA90258'}, {'DAI62779', 'SNA90258', 'GRO88505'}, {'DAI62779', 'GRO89148', 'SNA90258'}, {'DAI62779', 'SNA90258', 'GRO29598'}, {'DAI62779', 'DAI85309', 'SNA90258'}, {'DAI62779', 'SNA90258', 'FRO19221'}, {'DAI62779', 'DAI87448', 'SNA90258'}, {'DAI62779', 'SNA90258', 'DAI92600'}, {'DAI62779', 'SNA90258', 'ELE17451'}, {'DAI62779', 'GRO99222', 'SNA90258'}, {'DAI62779', 'SNA90258', 'SNA30755'}, {'DAI62779', 'ELE26917', 'SNA90258'}, {'DAI62779', 'SNA99873', 'SNA90258'}, {'DAI62779', 'SNA90258', 'GRO56989'}, {'DAI62779', 'SNA90258', 'FRO78087'}, {'DAI62779', 'SNA90258', 'GRO94758'}, {'DAI62779', 'SNA47306', 'SNA90258'}, {'DAI62779', 'SNA90258', 'DAI38969'}, {'DAI62779', 'FRO32293', 'SNA90258'}, {'DAI62779', 'SNA90258', 'FRO98729'}, {'DAI62779', 'DAI95741', 'SNA90258'}, {'DAI62779', 'GRO30386', 'SNA90258'}, {'DAI62779', 'DAI35347', 'SNA90258'}, {'DAI62779', 'SNA90258', 'SNA93860'}, {'DAI62779', 'GRO15017', 'SNA90258'}, {'DAI62779', 'GRO59710', 'SNA90258'}, {'DAI62779', 'ELE66600', 'SNA90258'}, {'DAI6277 ...

# %%
f_k = generate_f_k(sc, c_k, shared_itemset, sup)
print(f_k)
# Out:
# [({'GRO73461', 'FRO40251', 'GRO85051'}, 147), ({'FRO73056', 'GRO73461', 'GRO44993'}, 106), ({'GRO73461', 'DAI43223', 'ELE32164'}, 111), ({'DAI88807', 'SNA72163', 'GRO73461'}, 110), ({'GRO73461', 'FRO40251', 'DAI88079'}, 144), ({'GRO73461', 'FRO40251', 'SNA80324'}, 232), ({'DAI75645', 'GRO73461', 'SNA80324'}, 230), ({'DAI75645', 'GRO73461', 'FRO47962'}, 111), ({'DAI75645', 'GRO73461', 'ELE17451'}, 121), ({'DAI75645', 'GRO73461', 'FRO40251'}, 293), ({'GRO73461', 'DAI75645', 'GRO21487'}, 114), ({'GRO73461', 'DAI75645', 'GRO38814'}, 101), ({'GRO73461', 'DAI75645', 'GRO46854'}, 101), ({'GRO73461', 'GRO56726', 'FRO40251'}, 103), ({'GRO73461', 'FRO40251', 'ELE17451'}, 159), ({'GRO30386', 'GRO73461', 'ELE17451'}, 103), ({'GRO59710', 'GRO73461', 'ELE32164'}, 137), ({'DAI62779', 'DAI22896', 'GRO73461'}, 101), ({'DAI62779', 'FRO31317', 'GRO73461'}, 100), ({'DAI62779', 'GRO73461', 'ELE32164'}, 131), ({'DAI62779', 'GRO73461', 'SNA80324'}, 198), ({'DAI62779', 'DAI75645', 'GRO73461'}, 261), ({'DAI62779', 'GRO73461', 'SNA96271'}, 114), ({'DAI62779', 'GRO71621', 'GRO73461'}, 153), ({'DAI62779', 'DAI85309', 'GRO73461'}, 179), ({'DAI62779', 'GRO73461', 'FRO19221'}, 142), ({'DAI62779', 'GRO73461', 'ELE17451'}, 245), ({'DAI62779', 'GRO30386', 'GRO73461'}, 186), ({'DAI62779', 'SNA55762', 'GRO73461'}, 109), ({'DAI62779', 'GRO73461', 'SNA45677'}, 112), ({'DAI62779', 'GRO73461', 'FRO40251'}, 315), ({'DAI62779', 'GRO21487', 'GRO73461'}, 173), ({'DAI62779', 'GRO38814', 'GRO73461'}, 154), ({'DAI62779', 'GRO46854', 'GRO73461'}, 135), ({'GRO69543', 'GRO73461', 'FRO40251'}, 111), ({'GRO73461', 'GRO21487', 'FRO40251'}, 182), ({'GRO73461', 'GRO38814', 'FRO40251'}, 106), ({'GRO73461', 'GRO46854', 'FRO40251'}, 106), ({'FRO92469', 'GRO73461', 'FRO40251'}, 211), ({'SNA59903', 'SNA72163', 'DAI88807'}, 140), ({'SNA59903', 'SNA72163', 'ELE17451'}, 127), ({'SNA59903', 'DAI88807', 'ELE17451'}, 120), ({'DAI62779', 'SNA59903', 'SNA72163'}, 121), ({'DAI62779', 'SNA59903', 'ELE17451'}, 202), ({'FRO40251', 'GRO85051', 'DAI55911'}, 133), ({'DAI62779', 'FRO31317', 'ELE17451'}, 106), ({'DAI88807', 'SNA72163', 'ELE17451'}, 105), ({'DAI62779', 'DAI88807', 'SNA72163'}, 104), ({'DAI62779', 'SNA72163', 'ELE17451'}, 107), ({'DAI85309', 'SNA18336', 'ELE17451'}, 119), ({'DAI62779', 'SNA18336', 'ELE32164'}, 100), ({'DAI62779', 'DAI85309', 'SNA18336'}, 151), ({'DAI62779', 'SNA18336', 'ELE17451'}, 244), ({'DAI62779', 'SNA18336', 'GRO15017'}, 105), ({'DAI62779', 'SNA18336', 'FRO40251'}, 102), ({'DAI62779', 'DAI42493', 'SNA18336'}, 109), ({'ELE92920', 'DAI85309', 'SNA18336'}, 139), ({'ELE92920', 'SNA18336', 'ELE17451'}, 228), ({'ELE92920', 'SNA18336', 'DAI62779'}, 432), ({'DAI62779', 'DAI91290', 'ELE17451'}, 109), ({'SNA80324', 'GRO85051', 'ELE17451'}, 158), ({'DAI75645', 'SNA80324', 'GRO85051'}, 192), ({'DAI75645', 'FRO40251', 'GRO85051'}, 395), ({'ELE20847', 'FRO40251', 'GRO85051'}, 139), ({'ELE26917', 'FRO40251', 'GRO85051'}, 146), ({'DAI62779', 'SNA80324', 'GRO85051'}, 205), ({'DAI62779', 'DAI75645', 'GRO85051'}, 154), ({'DAI62779', 'ELE17451', 'GRO85051'}, 178), ({'DAI62779', 'FRO40251', 'GRO85051'}, 381), ({'FRO40251', 'GRO85051', 'SNA80324'}, 471), ({'FRO40251', 'GRO85051', 'ELE17451'}, 217), ({'FRO40251', 'GRO85051', 'SNA45677'}, 107), ({'FRO40251', 'GRO85051', 'DAI31081'}, 102), ({'GRO21487', 'FRO40251', 'GRO85051'}, 120), ({'GRO38814', 'FRO40251', 'GRO85051'}, 115), ({'FRO53271', 'FRO40251', 'GRO85051'}, 105), ({'ELE17451', 'DAI43223', 'ELE32164'}, 206), ({'GRO59710', 'ELE17451', 'ELE32164'}, 202), ({'GRO59710', 'ELE32164', 'SNA45677'}, 100), ({'GRO59710', 'DAI43223', 'ELE32164'}, 287), ({'GRO59710', 'FRO53271', 'ELE32164'}, 105), ({'GRO59710', 'ELE32164', 'DAI31081'}, 112), ({'DAI62779', 'DAI85309', 'ELE32164'}, 141), ({'DAI62779', 'ELE17451', 'ELE32164'}, 277), ({'DAI62779', 'GRO30386', 'ELE32164'}, 118), ({'DAI62779', 'GRO59710', 'ELE32164'}, 301), ({'DAI62779', 'DAI43223', 'ELE32164'}, 287), ({'ELE92920', 'DAI62779', 'ELE32164'}, 165), ({'DAI75645', 'FRO40251', 'DAI88079'},  ...

# %%
frequent_itemset.append(f_k)

# %%
def apriori(sc, f_input, f_output, min_sup):
    # read the raw data
    data = sc.textFile(f_input)
    # count the total number of samples
    n_samples = data.count()
    # min_sup to frequency
    sup = n_samples * min_sup
    # split sort
    itemset = data.map(lambda line: sorted([int(item) for item in line.strip().split(' ')]))
    # share the whole itemset with all workers
    shared_itemset = sc.broadcast(itemset.map(lambda x: set(x)).collect())
    # store for all freq_k
    frequent_itemset = []

    # prepare candidate_1
    k = 1
    c_k = itemset.flatMap(lambda x: set(x)).distinct().collect()
    c_k = [{x} for x in c_k]

    # when candidate_k is not empty
    while len(c_k) > 0:
        # generate freq_k
        Dprint("C{}: {}".format(k, c_k))
        f_k = generate_f_k(sc, c_k, shared_itemset, sup)
        Dprint("F{}: {}".format(k, f_k))

        frequent_itemset.append(f_k)
        # generate candidate_k+1
        k += 1
        c_k = generate_next_c([set(item) for item in map(lambda x: x[0], f_k)], k)

    # output the result to file system
    sc.parallelize(frequent_itemset, numSlices=1).saveAsTextFile(f_output)
    sc.stop()
